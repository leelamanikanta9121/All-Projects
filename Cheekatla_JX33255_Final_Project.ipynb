# %% [markdown]
# # Cheekatla_JX33255_Final_Project

# %%
conda install -c conda-forge imbalanced-learn
# Out:
# ...
# Solving environment: ...working... done
#
#
# Note: you may need to restart the kernel to use updated packages.## Package Plan ##
#
#   environment location: C:\Users\manikanta\anaconda33
#
#   added / updated specs:
#     - imbalanced-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.14.0               |   py39hcbf5309_0         1.0 MB  conda-forge
#     imbalanced-learn-0.7.0     |             py_1          97 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   imbalanced-learn   conda-forge/noarch::imbalanced-learn-0.7.0-py_1
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#
# ...

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#
#   environment location: C:\Users\manikanta\anaconda33
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-package-handling-1.9.0|   py39h8cc25b3_1         744 KB
#     pyjwt-2.4.0                |   py39haa95532_0          38 KB
#     ------------------------------------------------------------
#                                            Total:         782 KB
#
# The following packages will be REMOVED:
#
#   xmltodict-0.12.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   conda-package-han~                   1.7.3-py39h8cc25b3_1 --> 1.9.0-py39h8cc25b3_1
#   pyjwt                                2.1.0-py39haa95532_0 --> 2.4.0-py39haa95532_0
#
#
#
# ...
#
# ...

# %%
conda install -c conda-forge prettytable
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\manikanta\anaconda33
#
#   added / updated specs:
#     - prettytable
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     prettytable-3.5.0          |     pyhd8ed1ab_0          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          28 KB
#
# The following NEW packages will be INSTALLED:
#
#   prettytable        conda-forge/noarch::prettytable-3.5.0-pyhd8ed1ab_0
#
#
#
# ...
#
# prettytable-3.5.0    | 28 KB     |            |   0%
# prettytable-3.5.0    | 28 KB     | #####8     |  58%
# prettytable-3.5.0    | 28 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ...

# %%
conda install -c conda-forge xgboost
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\manikanta\anaconda33
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0          11 KB  conda-forge
#     libxgboost-1.5.0           |       hd77b12b_2         1.3 MB
#     py-xgboost-1.5.0           |   py39haa95532_2         156 KB
#     xgboost-1.5.0              |   py39haa95532_2          15 KB
#     ------------------------------------------------------------
#                                            Total:         1.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  conda-forge/win-64::_py-xgboost-mutex-2.0-cpu_0
#   libxgboost         pkgs/main/win-64::libxgboost-1.5.0-hd77b12b_2
# ...

# %%
import pandas as pd
import numpy as np  
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from imblearn.over_sampling import SMOTE
from prettytable import PrettyTable
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import time
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Figure out the time taken to read the datasets with the majix 
# The data has been taken from WHO(World health Organisation) which is an open source for the public
import pandas as pd 

data=pd.read_csv('vaccination-data.csv')

# %%
# %%time
data
# Out:
# Wall time: 0 ns
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2022-12-05
# 1              Albania  ALB       EURO   REPORTING   2022-11-27
# 2              Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3       American Samoa  ASM       WPRO   REPORTING   2022-08-23
# 4              Andorra  AND       EURO   REPORTING   2022-11-13
# ..                 ...  ...        ...         ...          ...
# 224           Viet Nam  VNM       WPRO   REPORTING   2022-12-01
# 225  Wallis and Futuna  WLF       WPRO   REPORTING   2022-07-26
# 226              Yemen  YEM       EMRO   REPORTING   2022-11-21
# 227             Zambia  ZMB       AFRO   REPORTING   2022-11-27
# 228           Zimbabwe  ZWE       AFRO   REPORTING   2022-11-13
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0            12304901.0                     11320910.0
# 1             3017443.0                      1341413.0
# ...

# %%
data.tail()
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 224           Viet Nam  VNM       WPRO   REPORTING   2022-12-01
# 225  Wallis and Futuna  WLF       WPRO   REPORTING   2022-07-26
# 226              Yemen  YEM       EMRO   REPORTING   2022-11-21
# 227             Zambia  ZMB       AFRO   REPORTING   2022-11-27
# 228           Zimbabwe  ZWE       AFRO   REPORTING   2022-11-13
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 224         264635919.0                     90349305.0
# 225             16782.0                         6592.0
# 226           1239152.0                      1003208.0
# 227          13405550.0                     10842123.0
# 228          12694853.0                      6558577.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 224                    271.872                                92.820
# 225                    149.226                                58.616
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               229 non-null    object
#  1   ISO3                                  229 non-null    object
#  2   WHO_REGION                            229 non-null    object
#  3   DATA_SOURCE                           229 non-null    object
#  4   DATE_UPDATED                          229 non-null    object
#  5   TOTAL_VACCINATIONS                    228 non-null    float64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         228 non-null    float64
#  7   TOTAL_VACCINATIONS_PER100             227 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  228 non-null    float64
#  9   PERSONS_FULLY_VACCINATED              229 non-null    int64
#  10  PERSONS_FULLY_VACCINATED_PER100       229 non-null    float64
# ...

# %%
data.columns
# Out:
# Index(['COUNTRY', 'ISO3', 'WHO_REGION', 'DATA_SOURCE', 'DATE_UPDATED',
#        'TOTAL_VACCINATIONS', 'PERSONS_VACCINATED_1PLUS_DOSE',
#        'TOTAL_VACCINATIONS_PER100', 'PERSONS_VACCINATED_1PLUS_DOSE_PER100',
#        'PERSONS_FULLY_VACCINATED', 'PERSONS_FULLY_VACCINATED_PER100',
#        'VACCINES_USED', 'FIRST_VACCINE_DATE', 'NUMBER_VACCINES_TYPES_USED',
#        'PERSONS_BOOSTER_ADD_DOSE', 'PERSONS_BOOSTER_ADD_DOSE_PER100'],
#       dtype='object')

# %%
print('length of the data is' , len(data))
# Out:
# length of the data is 229

# %%
data.shape
# Out:
# (229, 16)

# %%
#Checking  Null values/missing values
np.sum(data.isnull().any (axis=1))
# Out:
# 38

# %%
# Count of missing values in each column
data.isnull().sum()
# Out:
# COUNTRY                                  0
# ISO3                                     0
# WHO_REGION                               0
# DATA_SOURCE                              0
# DATE_UPDATED                             0
# TOTAL_VACCINATIONS                       1
# PERSONS_VACCINATED_1PLUS_DOSE            1
# TOTAL_VACCINATIONS_PER100                2
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     1
# PERSONS_FULLY_VACCINATED                 0
# PERSONS_FULLY_VACCINATED_PER100          0
# VACCINES_USED                            4
# FIRST_VACCINE_DATE                      22
# NUMBER_VACCINES_TYPES_USED               4
# PERSONS_BOOSTER_ADD_DOSE                23
# PERSONS_BOOSTER_ADD_DOSE_PER100         23
# dtype: int64

# %%
#Rows and Columns 
print('Count of Columns in the data is:  ', len(data.columns))
# Out:
# Count of Columns in the data is:   16

# %%
# Data Description
print('Count of rows in the data is:', len(data))
# Out:
# Count of rows in the data is: 229

# %%
data.describe()
# Out:
#        TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# count        2.280000e+02                   2.280000e+02
# mean         5.705278e+07                   2.390119e+07
# std          2.800370e+08                   1.134051e+08
# min          1.380000e+02                   0.000000e+00
# 25%          4.641722e+05                   1.914585e+05
# 50%          4.291372e+06                   2.528282e+06
# 75%          2.172771e+07                   1.013656e+07
# max          3.465114e+09                   1.307512e+09
#
#        TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# count                 227.000000                            228.000000
# mean                  149.212449                             62.160447
# std                    83.189854                             26.167877
# min                     0.248000                              0.000000
# 25%                    79.894000                             43.486250
# ...

# %%
# Univeriate Analysis
# Numeric features distribution

data.hist(figsize=(20,20),bins = 20, color="#107009AA")
plt.title("Numeric Features Distribution")
plt.show()

# %%
sns.countplot(data= data,  x = "TOTAL_VACCINATIONS")
plt.gcf().set_size_inches(20, 8)
plt.show()

# %% [markdown]
# data["COUNTRY"].value_counts().head(10).plot(kind = 'pie', autopct='%1.1f%%', figsize=(10, 10)).legend()

# %%
data["COUNTRY"].value_counts().head(10).plot(kind = 'pie', autopct='%1.1f%%', figsize=(10, 10)).legend()

# %%
# Region Distribution
plt.figure(figsize=(12,10))
sns.countplot(data.WHO_REGION)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'EMRO'),
#   Text(1, 0, 'EURO'),
#   Text(2, 0, 'AFRO'),
#   Text(3, 0, 'WPRO'),
#   Text(4, 0, 'AMRO'),
#   Text(5, 0, 'SEARO'),
#   Text(6, 0, 'OTHER')])

# %%
# Education
sns.countplot(data= data, x = "PERSONS_BOOSTER_ADD_DOSE_PER100")
plt.show()

# %%
data["PERSONS_BOOSTER_ADD_DOSE_PER100"].value_counts()
# Out:
# 0.000      2
# 13.116     1
# 54.098     1
# 56.286     1
# 2.998      1
#           ..
# 21.980     1
# 42.738     1
# 20.001     1
# 105.918    1
# 8.132      1
# Name: PERSONS_BOOSTER_ADD_DOSE_PER100, Length: 205, dtype: int64

# %%
plt.rcParams['figure.figsize'] = [15, 5]
score_bin = pd.crosstab(data.TOTAL_VACCINATIONS,data.PERSONS_BOOSTER_ADD_DOSE_PER100,normalize='index')
score_bin.plot.bar(stacked=True)
plt.legend(title='PERSONS_BOOSTER_ADD_DOSE_PER100',loc='upper left',bbox_to_anchor=(1, 0.5))

# %% [markdown]
# #  Feature Engineering

# %%
#Checking categorical type columns in the data
data.select_dtypes(include='object')
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2022-12-05
# 1              Albania  ALB       EURO   REPORTING   2022-11-27
# 2              Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3       American Samoa  ASM       WPRO   REPORTING   2022-08-23
# 4              Andorra  AND       EURO   REPORTING   2022-11-13
# ..                 ...  ...        ...         ...          ...
# 224           Viet Nam  VNM       WPRO   REPORTING   2022-12-01
# 225  Wallis and Futuna  WLF       WPRO   REPORTING   2022-07-26
# 226              Yemen  YEM       EMRO   REPORTING   2022-11-21
# 227             Zambia  ZMB       AFRO   REPORTING   2022-11-27
# 228           Zimbabwe  ZWE       AFRO   REPORTING   2022-11-13
#
#                                          VACCINES_USED FIRST_VACCINE_DATE
# 0    AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-C...         2021-02-22
# ...

# %%
#Encoding these categorical features into numeric type

pro= preprocessing.LabelEncoder()
encpro=pro.fit_transform((data['COUNTRY']).astype(str))
data['COUNTRY'] = encpro

pro= preprocessing.LabelEncoder()
encpro=pro.fit_transform((data['WHO_REGION']).astype(str))
data['WHO_REGION'] = encpro

pro= preprocessing.LabelEncoder()
encpro=pro.fit_transform((data['ISO3']).astype(str))
data['ISO3'] = encpro

pro= preprocessing.LabelEncoder()
encpro=pro.fit_transform((data['DATA_SOURCE']).astype(str))
data['DATA_SOURCE'] = encpro

pro= preprocessing.LabelEncoder()
encpro=pro.fit_transform((data['DATE_UPDATED']).astype(str))
data['DATE_UPDATED'] = encpro

pro= preprocessing.LabelEncoder()
encpro=pro.fit_transform((data['VACCINES_USED']).astype(str))
data['VACCINES_USED'] = encpro

pro= preprocessing.LabelEncoder()
encpro=pro.fit_transform((data['FIRST_VACCINE_DATE']).astype(str))
data['FIRST_VACCINE_DATE'] = encpro

# %%
#Bivariate Analysis
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(data.corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %% [markdown]
# ### promoted target is good correlated with the following features:
# # COUNTRY
# # ISO3
# # WHO_REGION
# # DATA_SOURCE
# # DATE_UPDATED
# # TOTAL_VACCINATIONS
# # PERSONS_VACCINATED_1PLUS_DOSE
# # TOTAL_VACCINATIONS_PER100
# # PERSONS_VACCINATED_1PLUS_DOSE_PER100
# # PERSONS_FULLY_VACCINATED
# #  PERSONS_FULLY_VACCINATED_PER100
# # VACCINES_USED
# # FIRST_VACCINE_DATE
# # NUMBER_VACCINES_TYPES_USED
# # PERSONS_BOOSTER_ADD_DOSE
# # PERSONS_BOOSTER_ADD_DOSE_PER100

# %%
#Missing value Treatment
data.isnull().sum()
# Out:
# COUNTRY                                  0
# ISO3                                     0
# WHO_REGION                               0
# DATA_SOURCE                              0
# DATE_UPDATED                             0
# TOTAL_VACCINATIONS                       1
# PERSONS_VACCINATED_1PLUS_DOSE            1
# TOTAL_VACCINATIONS_PER100                2
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     1
# PERSONS_FULLY_VACCINATED                 0
# PERSONS_FULLY_VACCINATED_PER100          0
# VACCINES_USED                            0
# FIRST_VACCINE_DATE                       0
# NUMBER_VACCINES_TYPES_USED               4
# PERSONS_BOOSTER_ADD_DOSE                23
# PERSONS_BOOSTER_ADD_DOSE_PER100         23
# dtype: int64

# %% [markdown]
# # Handling Missing Values

# %%
data.isnull().sum().sum()/len(data)
# Out:
# 0.24017467248908297

# %%
#lets calculate the total missing values in the each column
data_total = data.isnull().sum()
data_percent = ((data.isnull().sum()/data.shape[0])*100).round(2)
missing_data = pd.concat([data_total, data_percent],
                                axis=1 , 
                                keys=['Train_Total', 'Train_Percent %','Test_Total', 'Test_Percent %'],
                                sort = True)
missing_data.style.bar(color = ['gold'])
# Out:
# <style type="text/css">
# #T_49d29_row0_col0, #T_49d29_row0_col1, #T_49d29_row1_col0, #T_49d29_row1_col1, #T_49d29_row2_col0, #T_49d29_row2_col1, #T_49d29_row3_col0, #T_49d29_row3_col1, #T_49d29_row4_col0, #T_49d29_row4_col1, #T_49d29_row8_col0, #T_49d29_row8_col1, #T_49d29_row9_col0, #T_49d29_row9_col1, #T_49d29_row14_col0, #T_49d29_row14_col1, #T_49d29_row15_col0, #T_49d29_row15_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_49d29_row5_col0, #T_49d29_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 17.4%, transparent 17.4%);
# }
# #T_49d29_row6_col0, #T_49d29_row6_col1, #T_49d29_row7_col0, #T_49d29_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 100.0%, transparent 100.0%);
# }
# #T_49d29_row10_col0, #T_49d29_row11_col0, #T_49d29_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 4.3%, transparent 4.3%);
# }
# ...

# %%
#working on the previous_year_rating
py=data[data['PERSONS_BOOSTER_ADD_DOSE_PER100'].isnull()]
py.head()
# Out:
#     COUNTRY  ISO3  WHO_REGION  DATA_SOURCE  DATE_UPDATED  TOTAL_VACCINATIONS  \
# 0         0     1           2            1            59          12304901.0
# 10       10     0           1            1            57            173993.0
# 21       21    16           0            1            44           3694544.0
# 26       26    17           1            0             1             35845.0
# 27       27    23           3            1             2           1924950.0
#
#     PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 0                      11320910.0                     31.609
# 10                        90082.0                    162.967
# 21                      3209393.0                     30.475
# 26                        19109.0                    137.934
# 27                       943394.0                     58.700
#
#     PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# ...

# %%
py['PERSONS_FULLY_VACCINATED'].value_counts()
# Out:
# 10615628    1
# 38511       1
# 50762968    1
# 2120962     1
# 5938186     1
# 3531        1
# 78057291    1
# 5176311     1
# 5878232     1
# 2481414     1
# 237406      1
# 0           1
# 83911       1
# 297060      1
# 5575771     1
# 654119      1
# 397080      1
# 3621866     1
# 3335753     1
# 846080      1
# 16736       1
# 2692837     1
# 27459447    1
# Name: PERSONS_FULLY_VACCINATED, dtype: int64

# %% [markdown]
# # Most of the countries have been fully and partially vaccinated its total citizens. While some countries data is missing where the missing null values we will impute 0 values.

# %%
data['PERSONS_FULLY_VACCINATED'].fillna(value=0,inplace=True)

# %%
data['TOTAL_VACCINATIONS'] = data['TOTAL_VACCINATIONS'].fillna(data['TOTAL_VACCINATIONS'].mode()[0])
data['PERSONS_VACCINATED_1PLUS_DOSE'] = data['PERSONS_VACCINATED_1PLUS_DOSE'].fillna(data['PERSONS_VACCINATED_1PLUS_DOSE'].mode()[0])
data['TOTAL_VACCINATIONS_PER100'] = data['TOTAL_VACCINATIONS_PER100'].fillna(data['TOTAL_VACCINATIONS_PER100'].mode()[0])
data['PERSONS_VACCINATED_1PLUS_DOSE_PER100'] = data['PERSONS_VACCINATED_1PLUS_DOSE_PER100'].fillna(data['PERSONS_VACCINATED_1PLUS_DOSE_PER100'].mode()[0])
data['NUMBER_VACCINES_TYPES_USED'] = data['NUMBER_VACCINES_TYPES_USED'].fillna(data['NUMBER_VACCINES_TYPES_USED'].mode()[0])
data['PERSONS_BOOSTER_ADD_DOSE'] = data['PERSONS_BOOSTER_ADD_DOSE'].fillna(data['PERSONS_BOOSTER_ADD_DOSE'].mode()[0])
data['PERSONS_BOOSTER_ADD_DOSE_PER100'] = data['PERSONS_BOOSTER_ADD_DOSE_PER100'].fillna(data['PERSONS_BOOSTER_ADD_DOSE_PER100'].mode()[0])

# %%
data.isnull().sum()
# Out:
# COUNTRY                                 0
# ISO3                                    0
# WHO_REGION                              0
# DATA_SOURCE                             0
# DATE_UPDATED                            0
# TOTAL_VACCINATIONS                      0
# PERSONS_VACCINATED_1PLUS_DOSE           0
# TOTAL_VACCINATIONS_PER100               0
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    0
# PERSONS_FULLY_VACCINATED                0
# PERSONS_FULLY_VACCINATED_PER100         0
# VACCINES_USED                           0
# FIRST_VACCINE_DATE                      0
# NUMBER_VACCINES_TYPES_USED              0
# PERSONS_BOOSTER_ADD_DOSE                0
# PERSONS_BOOSTER_ADD_DOSE_PER100         0
# dtype: int64

# %% [markdown]
# # Target : Target are the Results like in this project 1 and 0 are Target.

# %% [markdown]
# # Inputs :Inputs are the data features that we feed into model like in this WHO_REGION ,VACCINES_USED,PERSONS_FULLY_VACCINATED,DATA_SOURCE are the inputs.

# %% [markdown]
# ### Testing Data
# We use testing data after training the model. We use this data to evalaute the performance that how the model perform after training. So in this way first we get predictions from the trained model without giving the Target and then we compare the true Target with predictions and get the performance of the model.

# %% [markdown]
# ## Separating input feature and label

# %%
x=data.drop(columns=['DATA_SOURCE'])
y=data['DATA_SOURCE']

# %%
x.head()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: DATA_SOURCE, dtype: int32

# %% [markdown]
# # Step4:  Model building - Logistic Regression(Random Forest Clssfier Model)

# %%
smt = SMOTE()
x_up, y_up = smt.fit_resample(x, y)

# %%
sns.countplot(data= data, x = y_up)
# Out:
# <AxesSubplot:xlabel='DATA_SOURCE', ylabel='count'>

# %%
x_train, x_test, y_train, y_test = train_test_split(x_up, y_up, test_size=0.3, random_state=2)

# %%
LR=RandomForestClassifier()
LR= LR.fit(x_train , y_train)
LR
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### Separating the 70% data for training data and 30% for testing data
# ### As we prepared all the data, now we are separating/splitting the all data into training data and testing data.
#
# ##### 70% data will be used in the training
# #### 30% data will be used to test the performance of the model.

# %%
x_train, x_test, y_train, y_test = train_test_split(x_up, y_up, test_size=0.4, random_state=2)

# %%
LR=RandomForestClassifier()
LR= LR.fit(x_train , y_train)
LR
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Step5: Evaluation of Trained model on test data

# %% [markdown]
# ### Accuracy is the number of correctly classify the promoted and notpromoted.
# ### Accuracy= Total number of correct predictions/Total number of predictions

# %%
print('Test set\n  Accuracy: {:0.2f}'.format(LR.score(x_test, y_test))) #the accuracy of the model on test data is given below
# Out:
# Test set
#   Accuracy: 0.99

# %%
y_pred = LR.predict(x_test) #getting predictions on the trained model

# %% [markdown]
# ### Precision Score on test data
# ### Precision measure the number of positive class predictions that actually belong to the positive class

# %%
print('Precision',round(f1_score(y_test, y_pred, average='micro'),3),'%')
# Out:
# Precision 0.992 %

# %% [markdown]
# ## Recall Score on test data
# ### Recall measures the number of positive class predictions made out of all positive records in the dataset

# %%
print('Recall',round(recall_score(y_test, y_pred, average='micro'),4),'%')
# Out:
# Recall 0.9924 %

# %% [markdown]
# # Step6: Conclusion
#
# The model is giving good results and taking reasonable time on training. As we can see we got 99% accuracy is good but still we can improve the model with different techniques of machine learning and with different algorithms.
#
# As this is a small dataset and we have cleaned all the data including missing values, we have got more accuracy.
